# %% [markdown]
# ## Conda env_init
#
# Commands in this ipynb create conda environment with the name "*cdna*" and install torch, huggingface transformers and datasets, and comet ml.
#
# They also set up the *cdna* env to be seen from python notebooks

# %%
# !python --version
# Out:
# Python 3.9.10

# %%
# !nvidia-smi
# Out:
# Mon Jun  6 16:13:25 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 470.57.02    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A40          On   | 00000000:27:00.0 Off |                    0 |
# |  0%   47C    P8    38W / 300W |      0MiB / 45634MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# set up conda
# !conda create --yes --name cdna
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jovyan/my-conda-envs/cdna
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate cdna
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !conda install -n cdna --yes pytorch==1.7.1 torchvision==0.8.2 torchaudio==0.7.2 cudatoolkit=11.0 -c pytorch
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jovyan/my-conda-envs/cdna
#
#   added / updated specs:
#     - cudatoolkit=11.0
#     - pytorch==1.7.1
#     - torchaudio==0.7.2
#     - torchvision==0.8.2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
# ...

# %%
# !conda install -n cdna --yes -c huggingface transformers datasets
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jovyan/my-conda-envs/cdna
#
#   added / updated specs:
#     - datasets
#     - transformers
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     abseil-cpp-20210324.2      |       h9c3ff4c_0        1010 KB  conda-forge
#     aiohttp-3.8.1              |   py38h0a891b7_1         574 KB  conda-forge
#     aiosignal-1.2.0            |     pyhd8ed1ab_0          12 KB  conda-forge
# ...

# %%
# !conda install -n cdna --yes -c comet_ml comet_ml
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jovyan/my-conda-envs/cdna
#
#   added / updated specs:
#     - comet_ml
#
#
# The following NEW packages will be INSTALLED:
#
#   comet_ml           comet_ml/noarch::comet_ml-3.31.3-py38
#   configobj          conda-forge/noarch::configobj-5.0.6-py_0
#   dulwich            conda-forge/linux-64::dulwich-0.20.43-py38h0a891b7_0
#   everett            comet_ml/noarch::everett-1.0.2-py_1
#   importlib_resourc~ conda-forge/noarch::importlib_resources-5.7.1-pyhd8ed1ab_1
#   jsonschema         conda-forge/noarch::jsonschema-4.6.0-pyhd8ed1ab_0
#   nvidia-ml          conda-forge/noarch::nvidia-ml-7.352.0-py_0
#   psutil             conda-forge/linux-64::psutil-5.9.1-py38h0a891b7_0
# ...

# %%
# https://medium.com/@nrk25693/how-to-add-your-conda-environment-to-your-jupyter-notebook-in-just-4-steps-abeab8b8d084
# !conda install -n cdna --yes -c anaconda ipykernel
# Out:
# ...
# Solving environment: done
# ^C
#
# CondaError: KeyboardInterrupt

# %%
# !conda install -n cdna --yes -c anaconda ipywidgets
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jovyan/my-conda-envs/cdna
#
#   added / updated specs:
#     - ipywidgets
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     argon2-cffi-21.3.0         |     pyhd3eb1b0_0          15 KB  anaconda
#     argon2-cffi-bindings-21.2.0|   py38h7f8727e_0          35 KB  anaconda
#     beautifulsoup4-4.11.1      |   py38h06a4308_0         182 KB  anaconda
#     bleach-4.1.0               |     pyhd3eb1b0_0         121 KB  anaconda
#     defusedxml-0.7.1           |     pyhd3eb1b0_0          24 KB  anaconda
#     ipython_genutils-0.2.0     |     pyhd3eb1b0_1          27 KB  anaconda
# ...

# %%
# !conda install git-lfs -n cdna --yes
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jovyan/my-conda-envs/cdna
#
#   added / updated specs:
#     - git-lfs
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     git-lfs-3.2.0              |       ha770c72_0         3.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   git-lfs            conda-forge/linux-64::git-lfs-3.2.0-ha770c72_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    anaconda::ca-certificates-2022.4.26-h~ --> conda-forge::ca-certificates-2022.5.18.1-ha878542_0
# ...

# %%
# !python -m ipykernel install --user --name=cdna
# Out:
# Installed kernelspec cdna in /home/jovyan/.local/share/jupyter/kernels/cdna
