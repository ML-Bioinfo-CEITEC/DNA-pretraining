# %% [markdown]
# <a href="https://colab.research.google.com/github/ML-Bioinfo-CEITEC/cDNA-pretraining/blob/main/models/training_20220714/Training_with_BPE__30k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qq transformers datasets comet_ml

# %%
# PARAMETERS

DATASET = "simecek/Human_DNA_v0_BPEtokenized_vocab30k"
HF_MODEL_NAME = "DNADebertaBPE30k"

LR = 5e-05
WD = 0.1

BATCH_SIZE = 16
ACCUMULATION = 4
HIDDEN_LAYERS = 6
MLM_P = 0.15
EPOCHS = 15

# %% [markdown]
# ## 0) Loading

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal in case you want to set this credential helper as the default
#
# git config --global credential.helper store

# %%
import os

os.environ['COMET_API_KEY'] = "uckBYzSuTQ0uUKVA42536dD7Q"

import comet_ml

# Commet Init
comet_ml.init(project_name="Training_20220714", api_key="uckBYzSuTQ0uUKVA42536dD7Q")
# Out:
# COMET INFO: Comet API key is valid
# COMET WARNING: running in Google Colab, but can't find mounted drive. Using HOME instead
# COMET WARNING: if drive is mounted, set COMET_CONFIG to save config there
# COMET INFO: Comet API key saved in /root/.comet.config

# %%
from datasets import load_dataset
datasets = load_dataset(DATASET)
datasets.set_format("torch")
datasets
# Out:
# Using custom data configuration simecek--Human_DNA_v0_BPEtokenized_vocab30k-392f22544bcaf23b
# Reusing dataset parquet (/root/.cache/huggingface/datasets/simecek___parquet/simecek--Human_DNA_v0_BPEtokenized_vocab30k-392f22544bcaf23b/0.0.0/7328ef7ee03eaf3f86ae40594d46a1cec86161704e02dd19f232d81eee72ade8)
#   0%|          | 0/2 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 936729
#     })
#     test: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 104085
#     })
# })

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM

tokenizer = AutoTokenizer.from_pretrained("Vlasta/DNA_BPE_max_vocab_30000_maxk_10_max_tokenlen_10")

# %% [markdown]
# ## 1) Training

# %%
from transformers import DebertaConfig, DebertaForMaskedLM, TrainingArguments, Trainer, DataCollatorForLanguageModeling

model_config = DebertaConfig(vocab_size=len(tokenizer.vocab), max_position_embeddings=512, num_hidden_layers=HIDDEN_LAYERS)
model_config
# Out:
# DebertaConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-07,
#   "max_position_embeddings": 512,
#   "max_relative_positions": -1,
#   "model_type": "deberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 6,
#   "pad_token_id": 0,
#   "pooler_dropout": 0,
#   "pooler_hidden_act": "gelu",
#   "pooler_hidden_size": 768,
#   "pos_att_type": null,
#   "position_biased_input": true,
#   "relative_attention": false,
#   "transformers_version": "4.20.1",
#   "type_vocab_size": 0,
#   "vocab_size": 30000
# }

# %%
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=True, mlm_probability=MLM_P)

model = DebertaForMaskedLM(config=model_config)
sum(p.numel() for p in model.parameters()) // 10**6
# Out:
# 66

# %%
training_args = TrainingArguments(
    output_dir='./model',          # output directory to where save model checkpoint
    evaluation_strategy="steps",    # evaluate each `logging_steps` steps
    overwrite_output_dir=True,      
    num_train_epochs=EPOCHS,            # number of training epochs, feel free to tweak
    per_device_train_batch_size=BATCH_SIZE, # the training batch size, put it as high as your GPU memory fits
    gradient_accumulation_steps=ACCUMULATION,  # accumulating the gradients before updating the weights
    per_device_eval_batch_size=BATCH_SIZE,  # evaluation batch size
    logging_steps=5000,             # evaluate, log and save model checkpoints every 1000 step
    save_steps=5000,
    fp16=True,
    load_best_model_at_end=True,  # whether to load the best model (in terms of loss) at the end of training
    save_total_limit=1,           # whether you don't have much space so you let only 5 model weights saved in the disk
    push_to_hub=True,
    hub_model_id=HF_MODEL_NAME,
    hub_strategy="every_save",
    learning_rate=LR,
    weight_decay=WD
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=datasets['train'],
    eval_dataset=datasets['test'],
)
# Out:
# /content/./model is already a clone of https://huggingface.co/simecek/DNADebertaBPE30k. Make sure you pull the latest changes with `repo.git_pull()`.
# Using cuda_amp half precision backend

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 936729
#   Num Epochs = 15
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 64
#   Gradient Accumulation steps = 4
#   Total optimization steps = 219540
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.ml https://www.comet.com/simecek/training-20220714/e1e411f308154db78dee888986aeba0e
#
# Automatic Comet.ml online logging enabled
#     <div>
#
#       <progress value='76311' max='219540' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 76311/219540 15:45:43 < 29:35:05, 1.34 it/s, Epoch 5.21/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5000</td>
#       <td>7.708500</td>
#       <td>7.603242</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>7.584800</td>
#       <td>7.571662</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>7.558600</td>
#       <td>7.557636</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>7.544100</td>
#       <td>7.546363</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>7.536200</td>
#       <td>7.543568</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>7.527800</td>
#       <td>7.531886</td>
#     </tr>
#     <tr>
#       <td>35000</td>
#       <td>7.480700</td>
#       <td>7.348495</td>
#     </tr>
#     <tr>
#       <td>40000</td>
#       <td>7.223300</td>
#       <td>6.713342</td>
#     </tr>
#     <tr>
#       <td>45000</td>
#       <td>6.433300</td>
#       <td>6.043492</td>
#     </tr>
#     <tr>
#       <td>50000</td>
#       <td>5.928000</td>
#       <td>5.715364</td>
#     </tr>
#     <tr>
#       <td>55000</td>
#       <td>5.703100</td>
#       <td>5.573688</td>
#     </tr>
#     <tr>
#       <td>60000</td>
#       <td>5.570100</td>
#       <td>5.468022</td>
#     </tr>
#     <tr>
#       <td>65000</td>
#       <td>5.474200</td>
#       <td>5.387437</td>
#     </tr>
#     <tr>
#       <td>70000</td>
#       <td>5.406800</td>
#       <td>5.334507</td>
#     </tr>
#     <tr>
#       <td>75000</td>
#       <td>5.358800</td>
#       <td>5.296277</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-5000
# Configuration saved in ./model/checkpoint-5000/config.json
# Model weights saved in ./model/checkpoint-5000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-10000
# Configuration saved in ./model/checkpoint-10000/config.json
# Model weights saved in ./model/checkpoint-10000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-15000
# Configuration saved in ./model/checkpoint-15000/config.json
# Model weights saved in ./model/checkpoint-15000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-5000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-20000
# Configuration saved in ./model/checkpoint-20000/config.json
# Model weights saved in ./model/checkpoint-20000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-10000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-25000
# Configuration saved in ./model/checkpoint-25000/config.json
# Model weights saved in ./model/checkpoint-25000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-15000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-30000
# Configuration saved in ./model/checkpoint-30000/config.json
# Model weights saved in ./model/checkpoint-30000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-20000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-35000
# Configuration saved in ./model/checkpoint-35000/config.json
# Model weights saved in ./model/checkpoint-35000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-25000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-40000
# Configuration saved in ./model/checkpoint-40000/config.json
# Model weights saved in ./model/checkpoint-40000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-30000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-45000
# Configuration saved in ./model/checkpoint-45000/config.json
# Model weights saved in ./model/checkpoint-45000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-35000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-50000
# Configuration saved in ./model/checkpoint-50000/config.json
# Model weights saved in ./model/checkpoint-50000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-40000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-55000
# Configuration saved in ./model/checkpoint-55000/config.json
# Model weights saved in ./model/checkpoint-55000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-45000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-60000
# Configuration saved in ./model/checkpoint-60000/config.json
# Model weights saved in ./model/checkpoint-60000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-50000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-65000
# Configuration saved in ./model/checkpoint-65000/config.json
# Model weights saved in ./model/checkpoint-65000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-55000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-70000
# Configuration saved in ./model/checkpoint-70000/config.json
# Model weights saved in ./model/checkpoint-70000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-60000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-75000
# Configuration saved in ./model/checkpoint-75000/config.json
# Model weights saved in ./model/checkpoint-75000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-65000] due to args.save_total_limit
#     <div>
#
#       <progress value='105696' max='219540' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [105696/219540 21:51:55 < 23:33:05, 1.34 it/s, Epoch 7.22/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5000</td>
#       <td>7.708500</td>
#       <td>7.603242</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>7.584800</td>
#       <td>7.571662</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>7.558600</td>
#       <td>7.557636</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>7.544100</td>
#       <td>7.546363</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>7.536200</td>
#       <td>7.543568</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>7.527800</td>
#       <td>7.531886</td>
#     </tr>
#     <tr>
#       <td>35000</td>
#       <td>7.480700</td>
#       <td>7.348495</td>
#     </tr>
#     <tr>
#       <td>40000</td>
#       <td>7.223300</td>
#       <td>6.713342</td>
#     </tr>
#     <tr>
#       <td>45000</td>
#       <td>6.433300</td>
#       <td>6.043492</td>
#     </tr>
#     <tr>
#       <td>50000</td>
#       <td>5.928000</td>
#       <td>5.715364</td>
#     </tr>
#     <tr>
#       <td>55000</td>
#       <td>5.703100</td>
#       <td>5.573688</td>
#     </tr>
#     <tr>
#       <td>60000</td>
#       <td>5.570100</td>
#       <td>5.468022</td>
#     </tr>
#     <tr>
#       <td>65000</td>
#       <td>5.474200</td>
#       <td>5.387437</td>
#     </tr>
#     <tr>
#       <td>70000</td>
#       <td>5.406800</td>
#       <td>5.334507</td>
#     </tr>
#     <tr>
#       <td>75000</td>
#       <td>5.358800</td>
#       <td>5.296277</td>
#     </tr>
#     <tr>
#       <td>80000</td>
#       <td>5.320300</td>
#       <td>5.262834</td>
#     </tr>
#     <tr>
#       <td>85000</td>
#       <td>5.289500</td>
#       <td>5.236216</td>
#     </tr>
#     <tr>
#       <td>90000</td>
#       <td>5.263400</td>
#       <td>5.208357</td>
#     </tr>
#     <tr>
#       <td>95000</td>
#       <td>5.241400</td>
#       <td>5.188666</td>
#     </tr>
#     <tr>
#       <td>100000</td>
#       <td>5.220800</td>
#       <td>5.170367</td>
#     </tr>
#     <tr>
#       <td>105000</td>
#       <td>5.200000</td>
#       <td>5.154608</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-80000
# Configuration saved in ./model/checkpoint-80000/config.json
# Model weights saved in ./model/checkpoint-80000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-70000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-85000
# Configuration saved in ./model/checkpoint-85000/config.json
# Model weights saved in ./model/checkpoint-85000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-75000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-90000
# Configuration saved in ./model/checkpoint-90000/config.json
# Model weights saved in ./model/checkpoint-90000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-80000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-95000
# Configuration saved in ./model/checkpoint-95000/config.json
# Model weights saved in ./model/checkpoint-95000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-85000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-100000
# Configuration saved in ./model/checkpoint-100000/config.json
# Model weights saved in ./model/checkpoint-100000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-90000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
# Saving model checkpoint to ./model/checkpoint-105000
# Configuration saved in ./model/checkpoint-105000/config.json
# Model weights saved in ./model/checkpoint-105000/pytorch_model.bin
# Deleting older checkpoint [model/checkpoint-95000] due to args.save_total_limit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-3435b262f1ae> in <module>()
# ----> 1 trainer.train()
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1411             resume_from_checkpoint=resume_from_checkpoint,
#    1412             trial=trial,
# -> 1413             ignore_keys_for_eval=ignore_keys_for_eval,
#    1414         )
#    1415
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1661                     tr_loss += tr_loss_step
#    1662
# -> 1663                 self.current_flos += float(self.floating_point_ops(inputs))
#    1664
#    1665                 # Optimizer step for deepspeed must be called on every step regardless of the value of gradient_accumulation_steps
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in floating_point_ops(self, inputs)
#    3079         """
#    3080         if hasattr(self.model, "floating_point_ops"):
# -> 3081             return self.model.floating_point_ops(inputs)
#    3082         else:
#    3083             return 0
#
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py in floating_point_ops(self, input_dict, exclude_embeddings)
#     950         """
#     951
# --> 952         return 6 * self.estimate_tokens(input_dict) * self.num_parameters(exclude_embeddings=exclude_embeddings)
#     953
#     954
#
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py in estimate_tokens(self, input_dict)
#     917         if not hasattr(self, "warnings_issued"):
#     918             self.warnings_issued = {}
# --> 919         if self.main_input_name in input_dict:
#     920             return input_dict[self.main_input_name].numel()
#     921         elif "estimate_tokens" not in self.warnings_issued:
#
# /usr/lib/python3.7/collections/__init__.py in __contains__(self, key)
#    1032
#    1033     # Modify __contains__ to work correctly when __missing__ is present
# -> 1034     def __contains__(self, key):
#    1035         return key in self.data
#    1036
#
# KeyboardInterrupt:

# %%
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 104085
#   Batch size = 16
#     <div>
#
#       <progress value='105696' max='219540' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [105696/219540 21:51:55 < 23:33:05, 1.34 it/s, Epoch 7.22/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5000</td>
#       <td>7.708500</td>
#       <td>7.603242</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>7.584800</td>
#       <td>7.571662</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>7.558600</td>
#       <td>7.557636</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>7.544100</td>
#       <td>7.546363</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>7.536200</td>
#       <td>7.543568</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>7.527800</td>
#       <td>7.531886</td>
#     </tr>
#     <tr>
#       <td>35000</td>
#       <td>7.480700</td>
#       <td>7.348495</td>
#     </tr>
#     <tr>
#       <td>40000</td>
#       <td>7.223300</td>
#       <td>6.713342</td>
#     </tr>
#     <tr>
#       <td>45000</td>
#       <td>6.433300</td>
#       <td>6.043492</td>
#     </tr>
#     <tr>
#       <td>50000</td>
#       <td>5.928000</td>
#       <td>5.715364</td>
#     </tr>
#     <tr>
#       <td>55000</td>
#       <td>5.703100</td>
#       <td>5.573688</td>
#     </tr>
#     <tr>
#       <td>60000</td>
#       <td>5.570100</td>
#       <td>5.468022</td>
#     </tr>
#     <tr>
#       <td>65000</td>
#       <td>5.474200</td>
#       <td>5.387437</td>
#     </tr>
#     <tr>
#       <td>70000</td>
#       <td>5.406800</td>
#       <td>5.334507</td>
#     </tr>
#     <tr>
#       <td>75000</td>
#       <td>5.358800</td>
#       <td>5.296277</td>
#     </tr>
#     <tr>
#       <td>80000</td>
#       <td>5.320300</td>
#       <td>5.262834</td>
#     </tr>
#     <tr>
#       <td>85000</td>
#       <td>5.289500</td>
#       <td>5.236216</td>
#     </tr>
#     <tr>
#       <td>90000</td>
#       <td>5.263400</td>
#       <td>5.208357</td>
#     </tr>
#     <tr>
#       <td>95000</td>
#       <td>5.241400</td>
#       <td>5.188666</td>
#     </tr>
#     <tr>
#       <td>100000</td>
#       <td>5.220800</td>
#       <td>5.170367</td>
#     </tr>
#     <tr>
#       <td>105000</td>
#       <td>5.200000</td>
#       <td>5.154608</td>
#     </tr>
#     <tr>
#       <td>105695</td>
#       <td>5.200000</td>
#       <td>5.151925</td>
#     </tr>
#   </tbody>
# </table><p>
# {'eval_loss': 5.151925086975098}

# %%
trainer.push_to_hub()
# Out:
# Saving model checkpoint to ./model
# Configuration saved in ./model/config.json
# Model weights saved in ./model/pytorch_model.bin
# Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# Upload file pytorch_model.bin:   0%|          | 3.34k/254M [00:00<?, ?B/s]
# Upload file runs/Jul14_08-43-26_fee7f16cab7a/events.out.tfevents.1657788215.fee7f16cab7a.741.0:  26%|##6      …
# To https://huggingface.co/simecek/DNADebertaBPE30k
#    c375de4..614d878  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Masked Language Modeling', 'type': 'fill-mask'}}
# To https://huggingface.co/simecek/DNADebertaBPE30k
#    614d878..bb16069  main -> main
# 'https://huggingface.co/simecek/DNADebertaBPE30k/commit/614d87812d64edfd1b900d20f67d8c044f6f15e6'
